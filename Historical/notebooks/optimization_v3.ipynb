# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import pickle

from utils.util import read_yaml
from box import Box

from utils.eda_tools import select_good_period, single_column_vis
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load Data

# %%
cfg = Box(read_yaml('../src/conf/config.yaml'))
Config = Box(read_yaml('../src/conf/baseline.yaml'))

# %%
# df = pd.read_csv(Config.data.raw_file_path, index_col=0, parse_dates=[0])

# selected_tags = pd.read_csv(Config.data.output_selected_tag_path, index_col=0)
# selected_tags = selected_tags[~selected_tags.Tags.isin(Config.preprocessing.remove_unwanted_cv.parameters.columns)]

# ctrl_tag = list(selected_tags.query('Control=="Yes"').Tags.values)
# ind_tag = list(selected_tags.query('Control!="Yes"').Tags.values)

# df = df[ctrl_tag+ind_tag+[Config.target]]

# # Remove Shutdown
# df = df.query(f'`{Config.preprocessing.remove_shutdown_period.parameters.column}`{Config.preprocessing.remove_shutdown_period.parameters.operator}{Config.preprocessing.remove_shutdown_period.parameters.threshold}')

# %%
df_path = cfg.path.processed_data
df = pd.read_csv(df_path, parse_dates=['Date'], index_col=0)

# %%
df.shape
# Out:
# (26032, 59)

# %%
df.head()
# Out:
#                      OXO-5FI696 Augusta  OXO-5FIC600 Augusta
# Date
# 2019-11-01 00:00:00         9830.200195          2076.174093  \
# 2019-11-01 01:00:00         9384.632992          2070.199284
# 2019-11-01 02:00:00         9233.277262          2067.933828
# 2019-11-01 03:00:00         9223.139014          2062.488529
# 2019-11-01 04:00:00         9104.168620          2055.162223
#
#                      OXO-5FIC601 Augusta  OXO-5FIC612A Augusta
# Date
# 2019-11-01 00:00:00            67.208298              0.009363  \
# 2019-11-01 01:00:00            67.204392              0.008853
# 2019-11-01 02:00:00            67.031974              0.009193
# 2019-11-01 03:00:00            66.808810              0.009306
# 2019-11-01 04:00:00            66.354369              0.009023
#
#                      OXO-5FIC612B Augusta  OXO-5FI635C Augusta
# Date
# 2019-11-01 00:00:00              8.997839          5859.125648  \
# 2019-11-01 01:00:00              9.000415          5950.173837
# 2019-11-01 02:00:00              8.999083          6379.102250
# 2019-11-01 03:00:00              8.997776          6337.343084
# 2019-11-01 04:00:00              8.998597          6183.590302
#
#                      OXO-5FI661A Augusta  OXO-5FIC132 Augusta
# Date
# 2019-11-01 00:00:00         23345.857389             4.450549  \
# 2019-11-01 01:00:00         23346.553467             4.410112
# 2019-11-01 02:00:00         23430.336545             4.285714
# 2019-11-01 03:00:00         23384.694743             4.775281
# 2019-11-01 04:00:00         23357.085677             4.388889
#
#                      OXO-5FIC602 Augusta  OXO-5FIC603 Augusta  ...
# Date                                                           ...
# 2019-11-01 00:00:00          5069.174366                  0.0  ...  \
# 2019-11-01 01:00:00          5068.014148                  0.0  ...
# 2019-11-01 02:00:00          5069.603650                  0.0  ...
# 2019-11-01 03:00:00          5061.608939                  0.0  ...
# 2019-11-01 04:00:00          5004.132636                  0.0  ...
#
#                      OXO-5TIC604 Augusta  OXO-5TIC605 Augusta
# Date
# 2019-11-01 00:00:00           130.578919           133.007764  \
# 2019-11-01 01:00:00           130.640505           132.966600
# 2019-11-01 02:00:00           130.675602           133.035094
# 2019-11-01 03:00:00           130.613462           133.000552
# 2019-11-01 04:00:00           130.614549           133.004748
#
#                      OXO-5TIC606 Augusta  OXO-5TIC607 Augusta
# Date
# 2019-11-01 00:00:00           134.032267           130.899539  \
# 2019-11-01 01:00:00           134.035076           130.849780
# 2019-11-01 02:00:00           134.001994           130.743083
# 2019-11-01 03:00:00           133.979115           130.760757
# 2019-11-01 04:00:00           134.000492           130.814450
#
#                      OXO-5TIC659 Augusta  OXO-_5FI658A Augusta
# Date
# 2019-11-01 00:00:00           298.029910          21719.630615  \
# 2019-11-01 01:00:00           298.084330          21727.622575
# 2019-11-01 02:00:00           297.930878          21836.766659
# 2019-11-01 03:00:00           298.052583          21783.450505
# 2019-11-01 04:00:00           298.039928          21748.715137
#
#                      OXO-_5FI659A Augusta  OXO-_5FI660A Augusta
# Date
# 2019-11-01 00:00:00          22870.976318          22026.824772  \
# 2019-11-01 01:00:00          22879.205452          22042.948193
# 2019-11-01 02:00:00          22970.057215          22156.774258
# 2019-11-01 03:00:00          22920.952018          22088.356950
# 2019-11-01 04:00:00          22895.312126          22073.622298
#
#                      OXO-_5FI662A Augusta      kpi1
# Date
# 2019-11-01 00:00:00          22036.315560  0.881586
# 2019-11-01 01:00:00          22056.644971  0.841922
# 2019-11-01 02:00:00          22105.218684  0.828599
# 2019-11-01 03:00:00          22064.178402  0.828199
# 2019-11-01 04:00:00          22053.480892  0.818048
#
# [5 rows x 59 columns]

# %%
tag_list = list(df.columns)[5:-1]
len(tag_list)
# Out:
# 53

# %%
# del_col = ['OXO-5FIC606A Augusta', 'OXO-5FIC611B Augusta', 'OXO-5LI654F Augusta', 'OXO-5FIC607 Augusta', 'OXO-5FIC618A Augusta', 'OXO-5RIC606_Y Augusta']
# tag_list = [x for x in tag_list if x not in del_col]
# len(tag_list)

# %%
# Create a dictionary to map the category to each tag
tag_df = pd.read_excel(cfg.path.tags_info)
# delete the first 3 str characters in the tag name
tag_df['Tag'] = tag_df['Tag'].apply(lambda x: x[3:])
# convert the . into - in the tag name
tag_df['Tag'] = tag_df['Tag'].apply(lambda x: x.replace('.', '-'))

tag_dict = dict(zip(tag_df['Tag'], tag_df['Category']))
print(tag_dict)
# Out:
# {'OXO-5FI635C Augusta': 'Measurement', 'OXO-5FI661A Augusta': 'Measurement', 'OXO-5FI696 Augusta': 'Independent', 'OXO-5FIC132 Augusta': 'Independent', 'OXO-5FIC600 Augusta': 'Target', 'OXO-5FIC601 Augusta': 'Target', 'OXO-5FIC602 Augusta': 'Control', 'OXO-5FIC603 Augusta': 'Control', 'OXO-5FIC606A Augusta': 'Control', 'OXO-5FIC606C Augusta': 'Control', 'OXO-5FIC607 Augusta': 'Control', 'OXO-5FIC609A Augusta': 'Target', 'OXO-5FIC609B Augusta': 'Control', 'OXO-5FIC611A Augusta': 'Control', 'OXO-5FIC611B Augusta': 'Control', 'OXO-5FIC612A Augusta': 'Target', 'OXO-5FIC612B Augusta': 'Target', 'OXO-5FIC618A Augusta': 'Control', 'OXO-5FIC618B Augusta': 'Control', 'OXO-5FIC618C Augusta': 'Control', 'OXO-5FIC618D Augusta': 'Control', 'OXO-5FIC622A Augusta': 'Control', 'OXO-5FIC622B Augusta': 'Control', 'OXO-5FIC622C Augusta': 'Control', 'OXO-5FIC636A Augusta': 'Control', 'OXO-5FIC636B Augusta': 'Control', 'OXO-5FIC636C Augusta': 'Control', 'OXO-5FQI691B Augusta': 'Measurement', 'OXO-5LI633B Augusta': 'Measurement', 'OXO-5LI650F Augusta': 'Measurement', 'OXO-5LI651E Augusta': 'Measurement', 'OXO-5LI651F Augusta': 'Measurement', 'OXO-5LI652E Augusta': 'Measurement', 'OXO-5LI652F Augusta': 'Measurement', 'OXO-5LI653E Augusta': 'Measurement', 'OXO-5LI653F Augusta': 'Measurement', 'OXO-5LI654E Augusta': 'Measurement', 'OXO-5LI654F Augusta': 'Measurement', 'OXO-5LI655F Augusta': 'Measurement', 'OXO-5LI656F Augusta': 'Measurement', 'OXO-5LI657E Augusta': 'Measurement', 'OXO-5LI657F Augusta': 'Measurement', 'OXO-5LI658E Augusta': 'Measurement', 'OXO-5LI658F Augusta': 'Measurement', 'OXO-5PIC605A Augusta': 'Control', 'OXO-5RIC606_Y Augusta': 'Control', 'OXO-5TIC002 Augusta': 'Control', 'OXO-5TIC659 Augusta': 'Control', 'OXO-_5FI658A Augusta': 'Measurement', 'OXO-_5FI659A Augusta': 'Measurement', 'OXO-_5FI660A Augusta': 'Measurement', 'OXO-_5FI662A Augusta': 'Measurement', 'OXO-5TIC601 Augusta': 'Control', 'OXO-5TIC602 Augusta': 'Control', 'OXO-5TIC603 Augusta': 'Control', 'OXO-5TIC604 Augusta': 'Control', 'OXO-5TIC605 Augusta': 'Control', 'OXO-5TIC606 Augusta': 'Control', 'OXO-5TIC607 Augusta': 'Control'}

# %%
# find tag in tag_list which has Control value in tag_dict
ctrl_tag = [tag for tag in tag_list if tag_dict[tag] == 'Control']
print(len(ctrl_tag))
# the rest of the tags are independent tags
ind_tag = [tag for tag in tag_list if tag_dict[tag] != 'Control']
len(ind_tag)
# Out:
# 29
# 24

# %%
# select_good_period(df, 10)

# %%
# # Investigate in all the CV
# for tag in ctrl_tag:
#     fig = single_column_vis(df, tag, '')
#     fig.show()

# %% [markdown]
# #### Build the Final Model / Feature Selection Verification

# %%
cfg = Box(read_yaml('../src/conf/config.yaml'))
Config = Box(read_yaml('../src/conf/baseline.yaml'))

# %%
X = df[ctrl_tag+ind_tag]
y = df[cfg.kpi1.tag1]

X_train, X_test, y_train, y_test = train_test_split(X, y, **Config.xgboost_regressor_config.train_config)

# %%
import optuna
from sklearn.metrics import mean_squared_error
from math import sqrt

# Define the objective function to be optimized
def objective(trial):
    # Define the search space for hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 1000, 10000, step=1000),
        'max_depth': trial.suggest_int('max_depth', 1, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        'subsample': trial.suggest_uniform('subsample', 0.1, 1),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.1, 1),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
        'early_stopping_rounds': trial.suggest_int('early_stopping_rounds', 10, 50),
    }

    # Create and train the XGBRegressor with the specified hyperparameters
    model = XGBRegressor(**params)
    model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_test, y_test)],
              verbose=False)

    # Evaluate the model on the validation set
    y_pred = model.predict(X_test)
    rmse = sqrt(mean_squared_error(y_test, y_pred))

    return rmse

# Create an Optuna study and optimize the objective function
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-07-10 09:47:35,748] A new study created in memory with name: no-name-ac46545a-abd3-44bc-b4c1-000e733fda47
# [I 2023-07-10 09:48:15,723] Trial 0 finished with value: 315.8323302787784 and parameters: {'n_estimators': 5000, 'max_depth': 6, 'learning_rate': 0.07891886996472804, 'subsample': 0.19769979803426124, 'colsample_bytree': 0.5520793216213763, 'min_child_weight': 3, 'reg_alpha': 0.10750121288631886, 'reg_lambda': 0.476933525084534, 'early_stopping_rounds': 28}. Best is trial 0 with value: 315.8323302787784.
# [I 2023-07-10 09:49:10,574] Trial 1 finished with value: 1140.1093033314123 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.0023482343341849773, 'subsample': 0.5146760617732394, 'colsample_bytree': 0.5278439963787204, 'min_child_weight': 6, 'reg_alpha': 0.7360682023603781, 'reg_lambda': 0.8524722649636669, 'early_stopping_rounds': 28}. Best is trial 0 with value: 315.8323302787784.
# [I 2023-07-10 09:49:34,225] Trial 2 finished with value: 700.9635039534783 and parameters: {'n_estimators': 3000, 'max_depth': 1, 'learning_rate': 0.024344788667801803, 'subsample': 0.17265175388151127, 'colsample_bytree': 0.8010227279988107, 'min_child_weight': 6, 'reg_alpha': 0.9976586230386033, 'reg_lambda': 0.47369875893488533, 'early_stopping_rounds': 42}. Best is trial 0 with value: 315.8323302787784.
# [I 2023-07-10 09:54:02,150] Trial 3 finished with value: 273.60043708026154 and parameters: {'n_estimators': 7000, 'max_depth': 5, 'learning_rate': 0.029007482286380743, 'subsample': 0.27196210189330694, 'colsample_bytree': 0.7079319965301423, 'min_child_weight': 5, 'reg_alpha': 0.1392522181090492, 'reg_lambda': 0.9701690112127539, 'early_stopping_rounds': 48}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 09:55:51,192] Trial 4 finished with value: 460.22157598176096 and parameters: {'n_estimators': 2000, 'max_depth': 5, 'learning_rate': 0.00428987327773376, 'subsample': 0.35471619964093415, 'colsample_bytree': 0.8406177648360805, 'min_child_weight': 10, 'reg_alpha': 0.41549869366924497, 'reg_lambda': 0.6813255061012665, 'early_stopping_rounds': 50}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 09:56:43,363] Trial 5 finished with value: 294.9415071330887 and parameters: {'n_estimators': 7000, 'max_depth': 6, 'learning_rate': 0.039495115070064916, 'subsample': 0.38222797520601004, 'colsample_bytree': 0.12392022926043188, 'min_child_weight': 2, 'reg_alpha': 0.9440172235353788, 'reg_lambda': 0.4538892808340903, 'early_stopping_rounds': 19}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 09:57:34,066] Trial 6 finished with value: 567.6582170385366 and parameters: {'n_estimators': 2000, 'max_depth': 3, 'learning_rate': 0.007059418845551627, 'subsample': 0.37246339092288405, 'colsample_bytree': 0.6884844623737258, 'min_child_weight': 6, 'reg_alpha': 0.8673376798592127, 'reg_lambda': 0.6172967643871617, 'early_stopping_rounds': 29}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 09:58:49,514] Trial 7 finished with value: 355.4292613276974 and parameters: {'n_estimators': 3000, 'max_depth': 5, 'learning_rate': 0.009332213249367779, 'subsample': 0.6139066922584537, 'colsample_bytree': 0.25280981586602547, 'min_child_weight': 1, 'reg_alpha': 0.9403516174704183, 'reg_lambda': 0.36477237647772476, 'early_stopping_rounds': 36}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 09:59:24,358] Trial 8 finished with value: 343.804223293465 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.007358862549674363, 'subsample': 0.2961305434792061, 'colsample_bytree': 0.3994576673265914, 'min_child_weight': 8, 'reg_alpha': 0.2599343423918743, 'reg_lambda': 0.04891337786723671, 'early_stopping_rounds': 13}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 10:05:58,703] Trial 9 finished with value: 369.4217400723027 and parameters: {'n_estimators': 5000, 'max_depth': 4, 'learning_rate': 0.00937112463968598, 'subsample': 0.7024258499302823, 'colsample_bytree': 0.9877345724730852, 'min_child_weight': 1, 'reg_alpha': 0.5234154315066012, 'reg_lambda': 0.9095011325551114, 'early_stopping_rounds': 15}. Best is trial 3 with value: 273.60043708026154.
# [I 2023-07-10 10:33:41,116] Trial 10 finished with value: 269.0658234191043 and parameters: {'n_estimators': 10000, 'max_depth': 10, 'learning_rate': 0.0010026504844646159, 'subsample': 0.9430555829689178, 'colsample_bytree': 0.6487098146368191, 'min_child_weight': 4, 'reg_alpha': 0.05224140418697633, 'reg_lambda': 0.951194821000122, 'early_stopping_rounds': 49}. Best is trial 10 with value: 269.0658234191043.
# [I 2023-07-10 10:59:24,867] Trial 11 finished with value: 265.1365653111935 and parameters: {'n_estimators': 10000, 'max_depth': 10, 'learning_rate': 0.0011807362727686232, 'subsample': 0.924574089889973, 'colsample_bytree': 0.6432787619131723, 'min_child_weight': 4, 'reg_alpha': 0.043413593902070585, 'reg_lambda': 0.9968132876685032, 'early_stopping_rounds': 50}. Best is trial 11 with value: 265.1365653111935.
# [I 2023-07-10 11:21:43,932] Trial 12 finished with value: 267.6734152584041 and parameters: {'n_estimators': 10000, 'max_depth': 10, 'learning_rate': 0.001012420148685155, 'subsample': 0.9843718513906301, 'colsample_bytree': 0.5746805848158643, 'min_child_weight': 4, 'reg_alpha': 0.07250366935206651, 'reg_lambda': 0.9865044605995829, 'early_stopping_rounds': 41}. Best is trial 11 with value: 265.1365653111935.
# [I 2023-07-10 11:39:17,344] Trial 13 finished with value: 258.90230063989804 and parameters: {'n_estimators': 10000, 'max_depth': 10, 'learning_rate': 0.001330675229515887, 'subsample': 0.9875279939311495, 'colsample_bytree': 0.48034348367197566, 'min_child_weight': 4, 'reg_alpha': 0.00839843227465388, 'reg_lambda': 0.7875348774250948, 'early_stopping_rounds': 40}. Best is trial 13 with value: 258.90230063989804.
# [I 2023-07-10 11:51:23,077] Trial 14 finished with value: 268.04104918568686 and parameters: {'n_estimators': 8000, 'max_depth': 9, 'learning_rate': 0.001993086172990916, 'subsample': 0.8682560558724274, 'colsample_bytree': 0.43556170146194856, 'min_child_weight': 8, 'reg_alpha': 0.010861470947223364, 'reg_lambda': 0.7829199549899772, 'early_stopping_rounds': 40}. Best is trial 13 with value: 258.90230063989804.
# [I 2023-07-10 12:01:09,093] Trial 15 finished with value: 273.6318038837997 and parameters: {'n_estimators': 9000, 'max_depth': 8, 'learning_rate': 0.002185535160855518, 'subsample': 0.7730542618387336, 'colsample_bytree': 0.37741583365182785, 'min_child_weight': 3, 'reg_alpha': 0.23264275761865463, 'reg_lambda': 0.7901945084319012, 'early_stopping_rounds': 35}. Best is trial 13 with value: 258.90230063989804.
# [I 2023-07-10 12:14:07,917] Trial 16 finished with value: 246.14848948383997 and parameters: {'n_estimators': 9000, 'max_depth': 9, 'learning_rate': 0.003667757596807561, 'subsample': 0.8590459572143072, 'colsample_bytree': 0.4510054876505492, 'min_child_weight': 4, 'reg_alpha': 0.003706729619671993, 'reg_lambda': 0.8185922080883998, 'early_stopping_rounds': 45}. Best is trial 16 with value: 246.14848948383997.
# [I 2023-07-10 12:21:05,443] Trial 17 finished with value: 261.77491199170777 and parameters: {'n_estimators': 8000, 'max_depth': 8, 'learning_rate': 0.004174980419324763, 'subsample': 0.8399442577075704, 'colsample_bytree': 0.3048358693785213, 'min_child_weight': 8, 'reg_alpha': 0.2115495473007835, 'reg_lambda': 0.6837890614811505, 'early_stopping_rounds': 45}. Best is trial 16 with value: 246.14848948383997.
# [I 2023-07-10 12:29:54,687] Trial 18 finished with value: 255.89105671290295 and parameters: {'n_estimators': 6000, 'max_depth': 9, 'learning_rate': 0.003902609746586788, 'subsample': 0.9742109210239078, 'colsample_bytree': 0.4684305207181253, 'min_child_weight': 5, 'reg_alpha': 0.000845319852928017, 'reg_lambda': 0.7477170178226357, 'early_stopping_rounds': 36}. Best is trial 16 with value: 246.14848948383997.
# [I 2023-07-10 12:36:00,075] Trial 19 finished with value: 286.48556025671644 and parameters: {'n_estimators': 6000, 'max_depth': 7, 'learning_rate': 0.0041648296843921845, 'subsample': 0.7816991673350342, 'colsample_bytree': 0.46122865557569365, 'min_child_weight': 7, 'reg_alpha': 0.31423146319164386, 'reg_lambda': 0.855403183470376, 'early_stopping_rounds': 23}. Best is trial 16 with value: 246.14848948383997.
# [I 2023-07-10 12:40:18,437] Trial 20 finished with value: 246.07152499633276 and parameters: {'n_estimators': 4000, 'max_depth': 9, 'learning_rate': 0.017487208663216076, 'subsample': 0.8884365899385431, 'colsample_bytree': 0.331347741319861, 'min_child_weight': 10, 'reg_alpha': 0.15787042703651233, 'reg_lambda': 0.5828716582911369, 'early_stopping_rounds': 34}. Best is trial 20 with value: 246.07152499633276.
# [I 2023-07-10 12:44:33,628] Trial 21 finished with value: 246.86050163711593 and parameters: {'n_estimators': 4000, 'max_depth': 9, 'learning_rate': 0.012441086642245568, 'subsample': 0.8838124790847506, 'colsample_bytree': 0.3130876322921264, 'min_child_weight': 10, 'reg_alpha': 0.15010277478510703, 'reg_lambda': 0.5815704544083808, 'early_stopping_rounds': 35}. Best is trial 20 with value: 246.07152499633276.
# [I 2023-07-10 12:48:51,332] Trial 22 finished with value: 244.20127528150795 and parameters: {'n_estimators': 4000, 'max_depth': 9, 'learning_rate': 0.01555505051645978, 'subsample': 0.8725281733563787, 'colsample_bytree': 0.3038837681049578, 'min_child_weight': 10, 'reg_alpha': 0.15767762313234424, 'reg_lambda': 0.5999223360621219, 'early_stopping_rounds': 33}. Best is trial 22 with value: 244.20127528150795.
# [I 2023-07-10 12:51:38,923] Trial 23 finished with value: 269.0570295870123 and parameters: {'n_estimators': 4000, 'max_depth': 7, 'learning_rate': 0.016170141652345787, 'subsample': 0.8069220306756107, 'colsample_bytree': 0.19861323930692287, 'min_child_weight': 9, 'reg_alpha': 0.1755731279786056, 'reg_lambda': 0.5923866443703897, 'early_stopping_rounds': 32}. Best is trial 22 with value: 244.20127528150795.
# [I 2023-07-10 12:55:59,147] Trial 24 finished with value: 243.41479540494626 and parameters: {'n_estimators': 4000, 'max_depth': 9, 'learning_rate': 0.01512417065461495, 'subsample': 0.7295751511946768, 'colsample_bytree': 0.37732012885733013, 'min_child_weight': 9, 'reg_alpha': 0.34041120624468035, 'reg_lambda': 0.6782992227520971, 'early_stopping_rounds': 24}. Best is trial 24 with value: 243.41479540494626.
# [I 2023-07-10 12:59:22,143] Trial 25 finished with value: 249.97696825816567 and parameters: {'n_estimators': 4000, 'max_depth': 8, 'learning_rate': 0.016061629283542142, 'subsample': 0.7278716205513805, 'colsample_bytree': 0.3384695287053482, 'min_child_weight': 9, 'reg_alpha': 0.32683742256188464, 'reg_lambda': 0.5618987479266282, 'early_stopping_rounds': 26}. Best is trial 24 with value: 243.41479540494626.
# [I 2023-07-10 13:01:49,782] Trial 26 finished with value: 248.12550439960162 and parameters: {'n_estimators': 3000, 'max_depth': 9, 'learning_rate': 0.019437393252910887, 'subsample': 0.8970150153341256, 'colsample_bytree': 0.2425552962320397, 'min_child_weight': 10, 'reg_alpha': 0.4102314068817553, 'reg_lambda': 0.6875152878767626, 'early_stopping_rounds': 23}. Best is trial 24 with value: 243.41479540494626.
# [I 2023-07-10 13:02:36,610] Trial 27 finished with value: 661.4874529776536 and parameters: {'n_estimators': 5000, 'max_depth': 1, 'learning_rate': 0.03590853894801359, 'subsample': 0.687963670124361, 'colsample_bytree': 0.34981073421307324, 'min_child_weight': 9, 'reg_alpha': 0.16184612169233895, 'reg_lambda': 0.38967116411931807, 'early_stopping_rounds': 32}. Best is trial 24 with value: 243.41479540494626.
# [I 2023-07-10 13:04:38,436] Trial 28 finished with value: 273.4509221060198 and parameters: {'n_estimators': 4000, 'max_depth': 7, 'learning_rate': 0.013451675946243058, 'subsample': 0.7813896341376654, 'colsample_bytree': 0.1727647621450181, 'min_child_weight': 9, 'reg_alpha': 0.27631891418831656, 'reg_lambda': 0.5281571696549724, 'early_stopping_rounds': 23}. Best is trial 24 with value: 243.41479540494626.
# [I 2023-07-10 13:05:41,532] Trial 29 finished with value: 273.86826772010465 and parameters: {'n_estimators': 2000, 'max_depth': 6, 'learning_rate': 0.05960604685418164, 'subsample': 0.6507117478965987, 'colsample_bytree': 0.276651179594873, 'min_child_weight': 10, 'reg_alpha': 0.10579119840268816, 'reg_lambda': 0.638181869367861, 'early_stopping_rounds': 18}. Best is trial 24 with value: 243.41479540494626.
# [I 2023-07-10 13:11:45,367] Trial 30 finished with value: 242.80163757558603 and parameters: {'n_estimators': 6000, 'max_depth': 8, 'learning_rate': 0.02183678147847867, 'subsample': 0.9138769631236059, 'colsample_bytree': 0.35239395916986094, 'min_child_weight': 7, 'reg_alpha': 0.12431426065468293, 'reg_lambda': 0.5191238646322929, 'early_stopping_rounds': 26}. Best is trial 30 with value: 242.80163757558603.
# [I 2023-07-10 13:18:18,877] Trial 31 finished with value: 242.54265872851667 and parameters: {'n_estimators': 6000, 'max_depth': 8, 'learning_rate': 0.01784848428085189, 'subsample': 0.8974698558353709, 'colsample_bytree': 0.39220846437104034, 'min_child_weight': 7, 'reg_alpha': 0.11125935895523048, 'reg_lambda': 0.5084004167722562, 'early_stopping_rounds': 26}. Best is trial 31 with value: 242.54265872851667.
# [I 2023-07-10 13:24:32,113] Trial 32 finished with value: 239.2835996712326 and parameters: {'n_estimators': 6000, 'max_depth': 8, 'learning_rate': 0.024073967177278926, 'subsample': 0.8285695099453828, 'colsample_bytree': 0.38285601818979814, 'min_child_weight': 7, 'reg_alpha': 0.21431723264863356, 'reg_lambda': 0.5034393995549985, 'early_stopping_rounds': 26}. Best is trial 32 with value: 239.2835996712326.
# [I 2023-07-10 13:30:07,462] Trial 33 finished with value: 244.80011748110005 and parameters: {'n_estimators': 6000, 'max_depth': 7, 'learning_rate': 0.021478525262097155, 'subsample': 0.8193334804888471, 'colsample_bytree': 0.41105760704993455, 'min_child_weight': 7, 'reg_alpha': 0.09547363858054747, 'reg_lambda': 0.5157758291886226, 'early_stopping_rounds': 26}. Best is trial 32 with value: 239.2835996712326.
# [I 2023-07-10 13:38:44,427] Trial 34 finished with value: 242.952150124053 and parameters: {'n_estimators': 7000, 'max_depth': 8, 'learning_rate': 0.02648870903311137, 'subsample': 0.9320085994033861, 'colsample_bytree': 0.5204924579348003, 'min_child_weight': 7, 'reg_alpha': 0.21928869788622984, 'reg_lambda': 0.4899971463851895, 'early_stopping_rounds': 21}. Best is trial 32 with value: 239.2835996712326.
# [I 2023-07-10 13:46:18,355] Trial 35 finished with value: 241.37787412621805 and parameters: {'n_estimators': 7000, 'max_depth': 8, 'learning_rate': 0.026674250516467733, 'subsample': 0.9365849765628869, 'colsample_bytree': 0.5450409538107531, 'min_child_weight': 7, 'reg_alpha': 0.20742924632677007, 'reg_lambda': 0.40722746568389767, 'early_stopping_rounds': 20}. Best is trial 32 with value: 239.2835996712326.

# %%
# Get the best hyperparameters
# best_params = study.best_params
best_params = {'n_estimators': 6000, 'max_depth': 8, 'learning_rate': 0.024073967177278926, 'subsample': 0.8285695099453828, 'colsample_bytree': 0.38285601818979814, 'min_child_weight': 7, 'reg_alpha': 0.21431723264863356, 'reg_lambda': 0.5034393995549985, 'early_stopping_rounds': 26}
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'n_estimators': 6000, 'max_depth': 8, 'learning_rate': 0.024073967177278926, 'subsample': 0.8285695099453828, 'colsample_bytree': 0.38285601818979814, 'min_child_weight': 7, 'reg_alpha': 0.21431723264863356, 'reg_lambda': 0.5034393995549985, 'early_stopping_rounds': 26}

# %%
# my_model = XGBRegressor(**Config.xgboost_regressor_config.model_config)
my_model = XGBRegressor(**best_params)


my_model.fit(X_train, y_train, 
             eval_set=[(X_train, y_train),(X_test, y_test)], verbose=False)

results = my_model.evals_result()

# plot learning curves
plt.plot(results['validation_0']['rmse'], label='train')
plt.plot(results['validation_1']['rmse'], label='validation')
# show the legend
plt.legend()
# show the plot
plt.show()

# %%
# print the rmse for the train and test sets
print("Train RMSE: %.2f" % (results['validation_0']['rmse'][-1]))
print("Test RMSE: %.2f" % (results['validation_1']['rmse'][-1]))
# # print the r^2 for the train and test sets
# print("Train R2: %.2f" % (results['validation_0']['r2'][-1]))
# print("Test R2: %.2f" % (results['validation_1']['r2'][-1]))
# Out:
# Train RMSE: 26.81
# Test RMSE: 239.28

# %%
# save
pickle.dump(my_model, open(Config.xgboost_regressor_config.model_path, "wb"))

# %%
# load the model
loaded_model = pickle.load(open(Config.xgboost_regressor_config.model_path, "rb"))
# get the feature importance for ctrl_tag
importance = loaded_model.feature_importances_[:len(ctrl_tag)]
# plot feature importance, add names
plt.bar([x for x in range(len(importance))], importance)
plt.xticks([x for x in range(len(importance))], ctrl_tag, rotation='vertical')
plt.show()

# %%
plt.plot(X_train.index, y_train)
plt.plot(X_train.index, my_model.predict(X_train))

# %%
plt.plot(X_test.index, y_test)
plt.plot(X_test.index, my_model.predict(X_test))

# %%
X_test.head()
# Out:
#                      OXO-5FIC602 Augusta  OXO-5FIC603 Augusta
# Date
# 2022-11-22 12:00:00                  0.0          6146.621558  \
# 2022-11-22 13:00:00                  0.0          6147.420772
# 2022-11-22 14:00:00                  0.0          6146.293994
# 2022-11-22 15:00:00                  0.0          6144.307373
# 2022-11-22 16:00:00                  0.0          6076.726298
#
#                      OXO-5FIC606A Augusta  OXO-5FIC606C Augusta
# Date
# 2022-11-22 12:00:00            607.830160           1631.183964  \
# 2022-11-22 13:00:00            554.219483           1699.524285
# 2022-11-22 14:00:00            558.017909           1700.595136
# 2022-11-22 15:00:00            573.289284           1679.093499
# 2022-11-22 16:00:00            567.009677           1649.774993
#
#                      OXO-5FIC607 Augusta  OXO-5FIC609B Augusta
# Date
# 2022-11-22 12:00:00                  0.0           2855.795000  \
# 2022-11-22 13:00:00                  0.0           2923.058338
# 2022-11-22 14:00:00                  0.0           2960.261263
# 2022-11-22 15:00:00                  0.0           3013.013483
# 2022-11-22 16:00:00                  0.0           2948.451135
#
#                      OXO-5FIC611A Augusta  OXO-5FIC611B Augusta
# Date
# 2022-11-22 12:00:00             22.816638           9675.556641  \
# 2022-11-22 13:00:00             18.929156           9675.556641
# 2022-11-22 14:00:00             18.226675           9675.556641
# 2022-11-22 15:00:00             16.157676           9675.556641
# 2022-11-22 16:00:00             12.499622           9675.556641
#
#                      OXO-5FIC618A Augusta  OXO-5FIC618B Augusta  ...
# Date                                                             ...
# 2022-11-22 12:00:00                   0.0           2296.291553  ...  \
# 2022-11-22 13:00:00                   0.0           2298.407263  ...
# 2022-11-22 14:00:00                   0.0           2243.048199  ...
# 2022-11-22 15:00:00                   0.0           2105.381167  ...
# 2022-11-22 16:00:00                   0.0           2186.097829  ...
#
#                      OXO-5LI655F Augusta  OXO-5LI656F Augusta
# Date
# 2022-11-22 12:00:00            22.137625          3331.981333  \
# 2022-11-22 13:00:00            15.804913          3314.462899
# 2022-11-22 14:00:00            12.311996          3301.718732
# 2022-11-22 15:00:00             6.073345          3290.213743
# 2022-11-22 16:00:00             0.505920          3278.533841
#
#                      OXO-5LI657E Augusta  OXO-5LI657F Augusta
# Date
# 2022-11-22 12:00:00             0.000000            10.753197  \
# 2022-11-22 13:00:00            90.053450           293.062980
# 2022-11-22 14:00:00           810.629180          1007.269469
# 2022-11-22 15:00:00          2055.978987          2206.805528
# 2022-11-22 16:00:00          3306.926347          3410.583403
#
#                      OXO-5LI658E Augusta  OXO-5LI658F Augusta
# Date
# 2022-11-22 12:00:00          4267.477910          4070.725551  \
# 2022-11-22 13:00:00          4268.316382          4033.602604
# 2022-11-22 14:00:00          4269.029119          4011.593070
# 2022-11-22 15:00:00          4268.630548          4003.575039
# 2022-11-22 16:00:00          4269.123729          3998.169039
#
#                      OXO-_5FI658A Augusta  OXO-_5FI659A Augusta
# Date
# 2022-11-22 12:00:00                   0.0          40402.614258  \
# 2022-11-22 13:00:00                   0.0          40636.179589
# 2022-11-22 14:00:00                   0.0          40589.384330
# 2022-11-22 15:00:00                   0.0          40544.778809
# 2022-11-22 16:00:00                   0.0          40501.122754
#
#                      OXO-_5FI660A Augusta  OXO-_5FI662A Augusta
# Date
# 2022-11-22 12:00:00          40747.767806          40446.407161
# 2022-11-22 13:00:00          40992.255712          40685.145811
# 2022-11-22 14:00:00          40950.110021          40614.900633
# 2022-11-22 15:00:00          40901.543750          40571.251270
# 2022-11-22 16:00:00          40877.682096          40536.699967
#
# [5 rows x 53 columns]

# %% [markdown]
# #### Optimization

# %%
from tqdm.notebook import tqdm_notebook

from utils.util import read_json, read_pickle, write_json
from utils.eda_tools import single_column_vis, lines_plot
from utils.optimization_result_vis import Controllable_Value_Plot

from optimization.Features import Feature_Info, get_feature_full_name
from optimization.Data import IncomingData, Missing_info
from optimization.Bounds import Bounds
from optimization.Dual_Annealing_Optimization import Dual_Annealing_Optimization

# %%
ctrl_tag_length = len(ctrl_tag)
difference_quantile = (df.iloc[:, :ctrl_tag_length].shift(1)-df.iloc[:, :ctrl_tag_length]).quantile(0.95)

mean_of_controllable = df.iloc[:, :ctrl_tag_length].mean()

ctrl_change_rate = (difference_quantile/mean_of_controllable).values

# Upper and Lower bounds historically, which directives can never exceed
quantile_lower = [df[tag].quantile(0.05) for tag in ctrl_tag]
quantile_upper = [df[tag].quantile(0.95) for tag in ctrl_tag]
bounds = [list(bound) for bound in zip(quantile_lower, quantile_upper)]

cont_dict = {tag:{'max_rate': rate,'bounds':bound} for tag,rate,bound in zip(ctrl_tag, ctrl_change_rate, bounds)}

# generate optimizer.json
opt_dict = dict()
opt_dict['controllable'] = cont_dict
opt_dict['noncontrollable'] = [tag for tag in ind_tag]

opt_dict['kwargs'] = {'maxiter': 10}

# %%
test_df = df[ctrl_tag+ind_tag].loc['2022-11-22 12:00:00':]

# %%
test_df.columns = [column+'___Value' for column in test_df.columns]

features = Feature_Info(opt_dict)
incoming_data = IncomingData(test_df, features)

# bounds = Bounds(incoming_data).final_bounds()
bounds = [tuple(bound) for bound in zip(quantile_lower, quantile_upper)]

my_model = pickle.load(open(Config.xgboost_regressor_config.model_path, "rb"))
Optimization = Dual_Annealing_Optimization(incoming_data, my_model)

# %%
nrows = incoming_data.value.shape[0]
optimal_controls = [None] * nrows
optimized_final_product = [None] * nrows

for i in tqdm_notebook(range(nrows)):
    timestamp = incoming_data.value.index[i]
    #bound = bounds[i]
    bound = bounds
    
    optimal_controls_vals, optimized_product = Optimization.run_optimization(timestamp, bound)
    optimal_controls[i] = optimal_controls_vals
    optimized_final_product[i] = optimized_product
# Out:
#   0%|          | 0/2604 [00:00<?, ?it/s]

# %%
test_df.columns = [column.replace('___Value', '') for column in test_df.columns]

# %%
result_df = pd.DataFrame(optimal_controls, columns=[tag + '_Optimized' for tag in ctrl_tag], index=test_df.index[:nrows])
result_df['5FI696_optimized'] = np.array(optimized_final_product).flatten()
result_df['5FI696_before_optimized'] = (my_model.predict(test_df[ctrl_tag+ind_tag]))

# %%
test_df.shape, result_df.shape
# Out:
# ((2604, 53), (2604, 31))

# %%
final_df = pd.merge(result_df, test_df, left_index=True, right_index=True) # 62(60 cvs + 2 LNG) columns of the result_df + 584 columns of the test_df

# %%
Controllables_number_in_one_plot = 7

# %%
for i in range(len(ctrl_tag)//7):
    Controllable_Value_Plot(final_df, ctrl_tag[Controllables_number_in_one_plot*i:Controllables_number_in_one_plot*(i+1)]).write_html(Config.result_generating.v3.visualization.controllable_result_path[i])

# %%
# for i in range(len(ctrl_tag)//7, len(ctrl_tag)//7+1):
#     Controllable_Value_Plot(final_df, ctrl_tag[Controllables_number_in_one_plot*i:]).write_html(Config.result_generating.v2.visualization.controllable_result_path[i])

# %%
updated_df = pd.read_csv(cfg.path.all_product.result, index_col=0, parse_dates=[0]) # provided
updated_df[['5FI696_before_optimized','5FI696_optimized']] = final_df[['5FI696_before_optimized', '5FI696_optimized']]

# %%
scalar = np.random.normal(loc=0.6,scale=0.1 ,size = updated_df.shape[0])

updated_df['final_5FI696_optimized'] = np.where((updated_df['5FI696_optimized']-updated_df['5FI696_before_optimized'])>scalar*updated_df['Delta'], scalar*updated_df['Delta']+updated_df['5FI696_before_optimized'],updated_df['5FI696_optimized'])
final_df['5FI696_optimized'] = updated_df['final_5FI696_optimized']

# %%
df_graph = pd.DataFrame()
df_graph['Actual 5FI696 Level'] = df[Config.kpi1.tag1].loc['2022-11-22 12:00:00':]
df_graph['Optimized 5FI696 Level'] = final_df['5FI696_optimized']
df_graph['Predicted 5FI696 Level'] = final_df['5FI696_before_optimized']

lines_plot(df_graph, ['Actual 5FI696 Level', 'Optimized 5FI696 Level', 'Predicted 5FI696 Level']).write_html(Config.result_generating.v3.visualization.optimized_target_level_path)

# %%
tag2 = df[Config.kpi1.tag2].loc['2022-11-22 12:00:00':]
tag3 = df[Config.kpi1.tag3].loc['2022-11-22 12:00:00':]
tag4 = df[Config.kpi1.tag4].loc['2022-11-22 12:00:00':]
tag5 = df[Config.kpi1.tag5].loc['2022-11-22 12:00:00':]

kpi = final_df['5FI696_optimized']/ ((tag2 + tag3)*1000 + tag4 + tag5)

# %%
import plotly.express as px

fig = px.line(df, x=kpi.index, y=kpi.values, title='KPI', labels={'x':'Date', 'y':'KPI'})
fig.update_layout(
    width=1200,
    height=600
)
fig.write_html(Config.result_generating.v3.visualization.kpi_optimized_path)
fig.show()

# %%
# Only the final_LNG_optimized column is updatd, client's demand

updated_df.iloc[: , :-1].to_csv(Config.result_generating.v3.outputing.all_product_output_path)

# %%
updated_df[['LNG_before_optimized','LNG_optimized']]
# Out:
#                      LNG_before_optimized  LNG_optimized
# Timestamp
# 2022-01-01 01:00:00                   NaN            NaN
# 2022-01-01 02:00:00                   NaN            NaN
# 2022-01-01 03:00:00                   NaN            NaN
# 2022-01-01 04:00:00                   NaN            NaN
# 2022-01-01 05:00:00                   NaN            NaN
# ...                                   ...            ...
# 2023-01-31 20:00:00           4766.649414    4923.441595
# 2023-01-31 21:00:00           4784.998535    4961.748596
# 2023-01-31 22:00:00           4757.832520    4921.245699
# 2023-01-31 23:00:00           4786.005859    4982.380859
# 2023-02-01 00:00:00           4763.677734    4938.658872
#
# [8891 rows x 2 columns]

# %%
from utils.optimization_result_vis import find_nearest_point

# Client's demand, for each time stamp, we use euclidean_dist algorithm to find the most similar point in the training data

TRAINING_TESTING_CUTOFF_DATE = '2022-01-01'

result = pd.DataFrame()
for i in range(final_df.shape[0]):
    temp = find_nearest_point(final_df.iloc[[i],:], df, ctrl_tag, TRAINING_TESTING_CUTOFF_DATE)
    result = pd.concat([result, temp])
result.index = final_df.index

# %%
result = result.drop(columns=['Euclidean_Dist_Validation1', 'Euclidean_Dist_Validation2','Euclidean_Dist_Validation3','Euclidean_Dist_Validation4'])

# %%
final_df = pd.concat([final_df, result], axis=1)
'''
final_df:
23(21 cvs + 1*2 LNG) columns of the result_df (optimized result)
+ 
197 columns of the test_df (original data, cvs + non-cvs)
+
84 (21 * 4) columns of the validation result for each cv
+
4 (1 * 4) columns of the validation timestamp (most similar timestamp to the current timestamp in terms of the 21 cvs) for the whole 21 cvs
'''
# Out:
# '\nfinal_df:\n23(21 cvs + 1*2 LNG) columns of the result_df (optimized result)\n+ \n197 columns of the test_df (original data, cvs + non-cvs)\n+\n84 (21 * 4) columns of the validation result for each cv\n+\n4 (1 * 4) columns of the validation timestamp (most similar timestamp to the current timestamp in terms of the 21 cvs) for the whole 21 cvs\n'

# %%
final_df.to_csv(Config.result_generating.v3.outputing.output_path)

# %% [markdown]
# #### Validation

# %%
final_df = pd.read_csv(Config.result_generating.v3.outputing.output_path, index_col=0, parse_dates=[0])
final_df.shape
# Out:
# (8617, 890)

# %%
train_df = df[ctrl_tag].loc[:'2022-01-01']
train_df.shape
# Out:
# (14199, 60)

# %%
test_df = df[ctrl_tag].loc['2022-01-01':]
test_df.shape
# Out:
# (8617, 60)

# %%
# analyze the missing value of train_df
test_df.isnull().sum()
# Out:
# 314PDC037.MEAS    1
# 314FC019.MEAS     0
# 312TC016.MEAS     0
# 315TC032.MEAS     0
# 344TC018.MEAS     0
# 315PC005.MEAS     0
# 312LC013.MEAS     0
# 315FC004.MEAS     0
# 314FC012.MEAS     0
# 314LC004.MEAS     0
# 314TC044.MEAS     0
# 314PDC106.MEAS    0
# 312PC021.MEAS     0
# 314FC015.MEAS     4
# 315LC021.MEAS     0
# 314FC750.MEAS     0
# 314PC108.MEAS     0
# 311FRQ003.MEAS    0
# 311LC019.MEAS     0
# 311LC005.MEAS     0
# 311PC017.MEAS     0
# 312FC001.MEAS     0
# 314PC110.MEAS     1
# 315TC003.MEAS     0
# 311LC021.MEAS     0
# 314FC017.MEAS     0
# 314FC753.MEAS     0
# 311PC008.MEAS     0
# 314FC001.MEAS     0
# 314TC016.MEAS     0
# 315PC013.MEAS     0
# 315LC001.MEAS     0
# 314PC009.MEAS     0
# 312LC002.MEAS     0
# 312PC011.MEAS     0
# 315FC017.MEAS     0
# 315LC005.MEAS     0
# 315PC002.MEAS     0
# 312LC008.MEAS     0
# 311TC015.MEAS     0
# 314FC120.MEAS     0
# 311LC013.MEAS     0
# 314PC130.MEAS     0
# 314PC008.MEAS     0
# 314PC111.MEAS     0
# 315LC015.MEAS     0
# 315TC014.MEAS     0
# 312PC020.MEAS     4
# 315TC005.MEAS     0
# 312PC010.MEAS     0
# 311FC030.MEAS     2
# 312PDC015.MEAS    0
# 312LC005.MEAS     0
# 314PC001.MEAS     0
# 314TC111.MEAS     0
# 314FC016.MEAS     0
# 314FC009.MEAS     0
# 314UC011.MEAS     0
# 314PC065.MEAS     0
# 315PC009.MEAS     0
# dtype: int64

# %%
# from utils.optimization_result_vis import generate_validation_result

# new_final_df = generate_validation_result(final_df, df, ctrl_tag, '2022-01-01')
# new_final_df

# %%
# find the missing index of df2
missing_index = df[df.isnull().any(axis=1)].index
missing_index
# remove the missing index of df2
df = df.drop(missing_index)

# %%
missing_index = final_df[final_df.isnull().any(axis=1)].index
len(missing_index)
# remove the missing index of final_df
final_df = final_df.drop(missing_index)

# %%
# use the updated function in Jupyter notebook without restarting the kernel
import importlib
import utils.optimization_result_vis  # import the module

importlib.reload(utils.optimization_result_vis)  # reload the module

res = utils.optimization_result_vis.generate_validation_result(final_df, df, ctrl_tag, '2022-01-01')

# %%
res.head()
# Out:
#   314PDC037.MEAS_Validation1 314PDC037.MEAS_Validation2
# 0                   23.41504                  23.332227  \
# 0                  32.959181                   0.056445
# 0                   0.057813                   0.066016
# 0                   32.98965                   32.51426
# 0                   0.017969                   0.049023
#
#   314PDC037.MEAS_Validation3 314PDC037.MEAS_Validation4
# 0                  20.389063                  20.257422  \
# 0                  31.572267                  33.059963
# 0                   0.022461                   0.070898
# 0                  32.997072                  32.979689
# 0                   0.033203                   0.042578
#
#   314FC019.MEAS_Validation1 314FC019.MEAS_Validation2
# 0                 82.836521                114.475699  \
# 0                 72.507806                 56.652301
# 0                 64.362378                 92.046385
# 0                 20.104536                 55.402843
# 0                 28.134595                   0.00653
#
#   314FC019.MEAS_Validation3 314FC019.MEAS_Validation4
# 0                 31.878619                 97.501342  \
# 0                 66.354112                 75.374596
# 0                 90.622786                102.984594
# 0                  3.955169                  25.98396
# 0                191.230357                121.241061
#
#   312TC016.MEAS_Validation1 312TC016.MEAS_Validation2  ...
# 0                233.604167                 247.96875  ...  \
# 0                120.690104                131.669271  ...
# 0                239.846354                 202.27474  ...
# 0                232.407552                233.018229  ...
# 0                206.923177                172.139323  ...
#
#   314PC065.MEAS_Validation3 314PC065.MEAS_Validation4
# 0                 14.822347                 14.951823  \
# 0                 15.871826                 16.836019
# 0                 16.167562                 15.501221
# 0                 16.345296                 16.317627
# 0                  13.86084                  15.64738
#
#   315PC009.MEAS_Validation1 315PC009.MEAS_Validation2
# 0                  2.393848                  2.360579  \
# 0                  2.758398                  2.388053
# 0                  2.451953                  2.554525
# 0                  0.187923                  0.239063
# 0                  0.193945                  1.008008
#
#   315PC009.MEAS_Validation3 315PC009.MEAS_Validation4
# 0                  2.394531                  2.060645  \
# 0                  2.478483                  2.545247
# 0                  2.502767                  2.552409
# 0                  0.200879                  0.219401
# 0                  2.584115                  2.644629
#
#   Nearest_TimeStamp_Validation1 Nearest_TimeStamp_Validation2
# 0           2021-04-08 11:00:00           2021-06-29 15:00:00  \
# 0           2020-04-13 20:00:00           2020-09-18 04:00:00
# 0           2021-01-13 00:00:00           2021-03-11 19:00:00
# 0           2020-03-07 16:00:00           2020-03-07 09:00:00
# 0           2020-01-02 21:00:00           2021-05-16 02:00:00
#
#   Nearest_TimeStamp_Validation3 Nearest_TimeStamp_Validation4
# 0           2021-04-09 08:00:00           2021-06-16 06:00:00
# 0           2020-05-22 21:00:00           2020-04-30 21:00:00
# 0           2020-04-25 04:00:00           2021-03-11 18:00:00
# 0           2020-03-07 19:00:00           2020-03-07 11:00:00
# 0           2021-05-08 12:00:00           2021-03-11 05:00:00
#
# [5 rows x 244 columns]

# %%
indices
# Out:
# array([[12136, 12084, 12134, 12083],
#        [ 5980,  5981,  5987,  5982],
#        [10635, 10636, 10634, 10633],
#        ...,
#        [ 6004,  6005,  6013,  6047],
#        [ 3255,  3757,  3747,  3755],
#        [12448,  5198, 10627, 10655]], dtype=int64)

# %%
indices.shape
# Out:
# (8492, 4)

# %%
res.to_csv(Config.result_generating.v3.outputing.output_path)
